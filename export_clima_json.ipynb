# %%
df = spark.sql("""
SELECT cidade, temperatura, data_hora
FROM delta.`/Volumes/projeto_api/pro_clima/gold/`
ORDER BY data_hora DESC
LIMIT 1
""")

# %%
df.write.mode("overwrite").json("/FileStore/clima.json")
